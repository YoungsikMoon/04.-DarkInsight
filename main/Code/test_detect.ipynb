# %%
import module.Test as test
import importlib
importlib.reload(test)
# %matplotlib inline

image_path = r'detection\input\test.jpg'
pt_file_path = r'detection\yolov7-w6-pose.pt'
t = test.Test(image_path, pt_file_path)
# Out:
# [(240.27618408203125, 336.5306091308594, 538.9949951171875, 420.7164611816406)]
